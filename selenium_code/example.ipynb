# %% [markdown]
# # Install Selenium
# `pip install selenium`
# # Install Driver
# chrome driver: https://sites.google.com/chromium.org/driver/
# firefox driver: https://github.com/mozilla/geckodriver/releases

# %% [markdown]
# # Browser Basic Control

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

#s = Service("./geckodriver.exe")
#driver = webdriver.Firefox(service=s)

driver.get("https://tw.appledaily.com/new/realtime")
time.sleep(1)


## 瀏覽器名稱
print(driver.name) 
print('===============')

## 網頁標題
print(driver.title)
print('===============')

## URL位置
print(driver.current_url)
print('===============')

## 連線Browser Id
print(driver.session_id)
print('===============')

## 瀏覽器功能設定選項
print(driver.capabilities)
print('===============')

## 目標網頁原始碼
print(driver.page_source)
print('===============')
driver.close()
# Out:
# chrome
# ...
# 即時 | 最新| 蘋果新聞網 | 蘋果日報
# ...
# https://tw.appledaily.com/realtime/new/
# ...
# 9cee84d5224e4dd731a797a5ceb0b92a
# ...
# {'acceptInsecureCerts': False, 'browserName': 'chrome', 'browserVersion': '99.0.4844.51', 'chrome': {'chromedriverVersion': '99.0.4844.51 (d537ec02474b5afe23684e7963d538896c63ac77-refs/branch-heads/4844@{#875})', 'userDataDir': 'C:\\Users\\user\\AppData\\Local\\Temp\\scoped_dir13736_2088698816'}, 'goog:chromeOptions': {'debuggerAddress': 'localhost:51544'}, 'networkConnectionEnabled': False, 'pageLoadStrategy': 'normal', 'platformName': 'windows', 'proxy': {}, 'setWindowRect': True, 'strictFileInteractability': False, 'timeouts': {'implicit': 0, 'pageLoad': 300000, 'script': 30000}, 'unhandledPromptBehavior': 'dismiss and notify', 'webauthn:extension:credBlob': True, 'webauthn:extension:largeBlob': True, 'webauthn:virtualAuthenticators': True}
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

#s = Service("./geckodriver.exe")
#driver = webdriver.Firefox(service=s)

driver.get("https://tw.appledaily.com/new/realtime")
time.sleep(1)

## 獲得初始化位置(左上角位置)
print(driver.get_window_position()) 
time.sleep(1)
## 設定初始化位置
print(driver.set_window_position(100,100)) 
time.sleep(1)
## 獲得視窗大小
print(driver.get_window_size()) 
time.sleep(1)
## 設定視窗大小
print(driver.set_window_size(1000,1000)) 
time.sleep(1)
## 視窗最大化
driver.maximize_window()
time.sleep(1)
## 視窗最小化
driver.minimize_window()
time.sleep(1)
## 模擬視窗最小化
driver.set_window_position(-3000,0)
time.sleep(1)
## 復原視窗大小
driver.set_window_position(0,0)
time.sleep(1)

driver.close()
# Out:
# {'x': 9, 'y': 9}
# {'height': 799, 'width': 1052, 'x': 100, 'y': 100}
# {'width': 1052, 'height': 799}
# None

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

#s = Service("./geckodriver.exe")
#driver = webdriver.Firefox(service=s)

## website you want to visit
website_urls = ["https://www.google.com/","https://www.youtube.com/","https://statementdog.com/"]

## visit the website in order

for url in website_urls:
        
    ## go to the website 
    driver.get(url)
    time.sleep(2) 
    
## 現在的網頁位置，會是網頁list中最後一個網頁位置
print(driver.current_url) # https://statementdog.com/
    
## 上一頁
driver.back()
time.sleep(1) 
print(driver.current_url) # https://www.youtube.com/
    
## 再上一頁
driver.back()
time.sleep(1)
print(driver.current_url) # https://www.google.com/
    
## 下一頁
driver.forward()
time.sleep(1)
print(driver.current_url) # https://www.youtube.com/
    
## 重新整理頁面
driver.refresh()
print(driver.current_url) # https://www.youtube.com/
    
## 關掉頁面
driver.close()
# Out:
# https://statementdog.com/
# https://www.youtube.com/
# https://www.google.com/
# https://www.youtube.com/
# https://www.youtube.com/

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = "https://statementdog.com"


driver.get(url) 
time.sleep(2)       

driver.save_screenshot("./test.png")
driver.close()

# %% [markdown]
# # Find Element and Send key

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

driver.get('https://google.com')

# locate the search box element
search_box = driver.find_element(By.NAME, 'q')

time.sleep(2)

# type in our search query into the search box
search_box.send_keys('Selenium' + Keys.RETURN)

time.sleep(3)

'''
search_box.send_keys('Selenium')
btn = driver.find_element(By.NAME, "btnK")
time.sleep(1)
btn.click()
'''

#driver.quit()
# Out:
# '\nsearch_box.send_keys(\'Selenium\')\nbtn = driver.find_element(By.NAME, "btnK")\ntime.sleep(1)\nbtn.click()\n'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

#設定瀏覽器啟動參數
#更多請參考 https://peter.sh/experiments/chromium-command-line-switches/

options = webdriver.ChromeOptions()
#options.add_argument('--start-fullscreen')
## 關掉通知
options.add_argument("-disable-notifications")

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s, options=options)

driver.get("https://www.google.com") # 更改網址以前往不同網頁

time.sleep(1)

element = driver.find_element(By.CLASS_NAME, "gLFyf.gsfi")
element.send_keys("Python")


time.sleep(1)
button = driver.find_element(By.CLASS_NAME, "gNO89b")

time.sleep(1)
button.click()

time.sleep(1)
elements = driver.find_elements(By.CLASS_NAME, "LC20lb.DKV0Md")

for i in elements:
    print(i.text)

    
#driver.close()
# Out:
# Welcome to Python.org
# Python - 維基百科，自由的百科全書
# Python 入門 - 在Django Girls Taipei 打造妳的第一個網站！
# 一小時Python入門-part 1 - 寫點科普
# Python - 博客來
# 老兵Python 再戰十年？這3大程式語言有望摘下新龍頭寶座嗎？

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time


s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

driver.get("http://www.google.com") # 更改網址以前往不同網頁

## 獲得搜尋欄的元素
search = driver.find_element(By.XPATH, '//input[@class="gLFyf gsfi"]')
## 傳入文字
search.send_keys("coding起來")
## 延遲時間
time.sleep(1)
## 獲得按鈕元素並觸發點擊事件
btn = driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]')

time.sleep(1)
btn.click()

#driver.close()

# %%
from selenium.webdriver.support.ui import Select
from selenium import webdriver


s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
#driver = webdriver.Firefox()

driver.get('http://sahitest.com/demo/selectTest.htm')

s1 = Select(driver.find_element(By.ID, 's1Id'))  

s1.select_by_index(1)  # 选择第二项选项：o1
#s1.select_by_value("o2")  # 选择value="o2"的项
#s1.select_by_visible_text("o3")  # 选择text="o3"的值，即在下拉时我们可以看到的文本

s2 = Select(driver.find_element(By.ID, 's2Id'))  
s2.select_by_index(2)  

s3 = Select(driver.find_element(By.ID, 's3Id'))  
s3.select_by_index(3) 


s4 = Select(driver.find_element(By.ID, 's4Id'))

s4.select_by_index(1)
s4.select_by_visible_text("With spaces")
s4.select_by_visible_text("    With nbsp")

print('s1 selected options:')
for select in s1.all_selected_options:
    print(select.text)

print('s2 selected options:')
for select in s2.all_selected_options:
    print(select.text)

print('s3 selected options:')
for select in s3.all_selected_options:
    print(select.text)

print('s4 selected options:')
for select in s4.all_selected_options:
    print(select.text)

#driver.quit()
# Out:
# s1 selected options:
# o1
# s2 selected options:
# o2
# s3 selected options:
# o3
# s4 selected options:
# o1
# With spaces
#     With nbsp

# %%
import time
from selenium import webdriver

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
# Maximize the browser window
driver.maximize_window()
# Navigate to Qxf2 Tutorial page
driver.get("http://qxf2.com/selenium-tutorial-main")

#KEY POINT: Code to fill forms
# Find the name field and fill name
name = driver.find_element_by_xpath("//input[@id='name']")  
name.send_keys('Avinash')
time.sleep(3)
# Find the email field and fill your email
driver.find_element_by_xpath("//input[@name='email']").send_keys('avinash@qxf2.com')
# Find the phone no field and fill phone no
phone = driver.find_element_by_id('phone')
phone.send_keys('9999999999')
time.sleep(3)
# Identify the xpath for Click me button and click on it 
button = driver.find_element_by_xpath("//button[text()='Click me!']")  
button.click()
# Wait for the new page to load
time.sleep(3)
# Verify user is taken to Qxf2 tutorial redirect url
if (driver.current_url== 'https://qxf2.com/selenium-tutorial-redirect'):
    print("Success")
else:
    print("Failure")

# Close the browser   
#driver.close()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_13064/4210998732.py:13: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   name = driver.find_element_by_xpath("//input[@id='name']")
# C:\Users\user\AppData\Local\Temp/ipykernel_13064/4210998732.py:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//input[@name='email']").send_keys('avinash@qxf2.com')
# C:\Users\user\AppData\Local\Temp/ipykernel_13064/4210998732.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   phone = driver.find_element_by_id('phone')
# C:\Users\user\AppData\Local\Temp/ipykernel_13064/4210998732.py:23: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   button = driver.find_element_by_xpath("//button[text()='Click me!']")
# ...
